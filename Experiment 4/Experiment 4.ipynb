# %% [markdown]
# #Experiment 4 - Operations on Tuple
# ##Ayush Phale
# ##PRN:25070123028
# ###ENTC BATCH:A2

# %%
##Python Tuples
##Access Tuple Items

thistuple = ("apple", "banana","cherry")
print(thistuple[1])
# Out:
# banana

# %%
thistuple = ("apple", "banana","cherry")
thistuple[1]= "blackcurrant"
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2944508203.py in <cell line: 0>()
#       1 thistuple = ("apple", "banana","cherry")
# ----> 2 thistuple[1]= "blackcurrant"
#       3 print(thistuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 =(1,2,3)
t2 = (4,5)
t3= t1+t2
print(t3)
# Out:
# (1, 2, 3, 4, 5)

# %%
#Add tuple to a tuple
thistuple = ("apple,""banana","cherry")
print("Before adding=",thistuple)
y=("orange",)
thistuple += y
print("After adding=",thistuple)
# Out:
# Before adding= ('apple,banana', 'cherry')
# After adding= ('apple,banana', 'cherry', 'orange')

# %%
#Address verification after apending new item in the tuple
thistuple = ("apple,""banana","cherry")
print("Before adding=",id(thistuple))
y=("orange",)
thistuple += y
print("After adding=",id(thistuple))
# Out:
# Before adding= 139938722821696
# After adding= 139938721995840

# %%
#Address verification after apending new item in the list
thistuple = ["apple,""banana","cherry"]
print("Before adding=",id(thistuple))
y=["orange",]
thistuple += y
print("After adding=",id(thistuple))
# Out:
# Before adding= 139938720523584
# After adding= 139938720523584

# %%
#Student marksheet
sheet = ("Maths",99,'A')
print("Student INFO:",(sheet))
#Check if the student has scored 75 or above marks and print "DIstinction" if the condition is satisfies
subject,marks,grade=sheet
if marks>=75:
  print("Distinction")
else:
  print("Failed")
# Out:
# Student INFO: ('Maths', 99, 'A')
# Distinction

# %%
#Attendance problem statement
attendance=("A","A","P","P","P","P","P")
print("Total number of presnt days=",attendance.count("P"))
print("Total number of absent days= ",attendance.count("A"))
if "A" in attendance:
  print("Employee was abesnt at least once in the week")
# Out:
# Total number of presnt days= 5
# Total number of absent days=  2
# Employee was abesnt at least once in the week
