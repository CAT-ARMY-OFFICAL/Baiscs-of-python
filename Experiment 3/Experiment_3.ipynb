# %% [markdown]
# #PRACTICAL 3
# ###Study of list & Various operations on it
# ##Ayush Phale PRN:25070123028
# ##EnTC Batch A2

# %%
## Python lists
thislist = ["apple", "guava", "watermelon"]
print(thislist)     ##Instead of doubl quotes, single quotes can be used, but preferred - double quotes
# Out:
# ['apple', 'guava', 'watermelon']

# %%
#Allow Duplicates
thislist = ["apple", "guava", "apple", "watermelon", "guava"]
print(thislist)
# Out:
# ['apple', 'guava', 'apple', 'watermelon', 'guava']

# %%
list1 = [1,2,'symbi', 54]
list1[0]
# Out:
# 1

# %%
#List Length
thislist = ["apple", 'guava', 'watermelon']
print(len(thislist))
# Out:
# 3

# %%
#A list with strings, integers, and boolean values:
list1 = ["abc", 34, True, 40, "female", False]  ##True & False are boolean functions

# %%
#Access Items
thislist = ["apple", "cherry", "litchi"]
print(thislist[1])
# Out:
# cherry

# %%
#Reverse/Negative Indexing
thislist = ["apple", "chery", "guava"]
print(thislist[-2])
# Out:
# chery

# %%
#Slicing
thislist = ["apple", "guava", "cherry","orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
#Slicing
thislist = ["apple", "guava", "cherry","orange", "kiwi", "melon", "mango"]
print(thislist[:4])
# Out:
# ['apple', 'guava', 'cherry', 'orange']

# %%
#Slicing
thislist = ["apple", "guava", "cherry","orange", "kiwi", "melon", "mango"]
print(thislist[-3:-1])
# Out:
# ['kiwi', 'melon']

# %%
#Slicing
thislist = ["apple", "guava", "cherry","orange", "kiwi", "melon", "mango"]
print(thislist[-3:])
# Out:
# ['kiwi', 'melon', 'mango']

# %%
#Change Item Value
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrent"
print(thislist)
# Out:
# ['apple', 'blackcurrent', 'cherry']

# %%
thislist = ["school", "college", "office"]
thislist[1] = "university"
thislist[2] = "workplace"
print(thislist)
# Out:
# ['school', 'university', 'workplace']

# %%
#Append Items
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")   #Append means to add it at the end
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
#Insert Items
thislist = ["apple", "banana", "cherry"]
thislist.insert(2,"orange")
print(thislist)
# Out:
# ['apple', 'banana', 'orange', 'cherry']

# %%
#Extend List
thislist = ["apple", "banana", "cherry"]
tropical = ["mango","pineappple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineappple', 'papaya']

# %%
8 in [3,4,5]
# Out:
# False

# %%
list = ('-Symbi')*6
#list1(1,2,3) - this will give error
print(list)
# Out:
# -Symbi-Symbi-Symbi-Symbi-Symbi-Symbi

# %%
L = ['spam', 'Spam', 'SPAM']
print(L[0])
# Out:
# spam

# %%
numbers = [10, 20, 30, 40, 50]
#Slicing examples
"Elements from index 1 to 3:"
"First three elements: "
"Elements from index 2 onwards: "
"All elements: "
# Out:
# 'All elements: '

# %%
#Problem Statements
marks = [99,80,78,56,39]
marks1 = max(marks)
print("The highest marks obtained is: ",marks1)
marks2 = min(marks)
print("The lowest marks obtaind is: ",marks2)
marks.sort()      #To arrange in ascending order
print(marks)
# Out:
# The highest marks obtained is:  99
# The lowest marks obtaind is:  39
# [39, 56, 78, 80, 99]

# %%
numbers = [1,2,3,4,5,6]
print(max(numbers))
print(min(numbers))
print(sum(numbers))
print(len(numbers))
numbers.sort()
print(numbers)
# Out:
# 6
# 1
# 21
# 6
# [1, 2, 3, 4, 5, 6]

# %%
#Grocery Shopping List

grocery = ["brinjal", "cauliflower", "onions","potato", "tomato"]
grocery.insert(3,"diet coke")
grocery.append("spices")
grocery.remove("brinjal")
print(grocery)
# Out:
# ['cauliflower', 'onions', 'diet coke', 'potato', 'tomato', 'spices']

# %%
#Phone Contacts problem statement
#Create a list of contacts, Add a new contact , Delete an exsisting contact , Display contacts
contacts= ["Ayush","Aditya","Anish","Aaryan","Athrav","Shourya"]
contacts.append("Vedang")
contacts.remove("Athrav")
contacts.sort()
print(contacts)
# Out:
# ['Aaryan', 'Aditya', 'Anish', 'Ayush', 'Shourya', 'Vedang']

# %%
#Temperatures for the first 5 days
temperatures=[29,28,28,25,29,28,27,28,27,28]
print("Temperatures for the first 5 day = ",temperatures[0:5])

#Temperatures for the last 5 days
print("Temperatures for last five days =",temperatures[5:10])
# Out:
# Temperatures for the first 5 day =  [29, 28, 28, 25, 29]
# Temperatures for last five days = [28, 27, 28, 27, 28]
